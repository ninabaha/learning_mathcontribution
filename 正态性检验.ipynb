# %% [markdown]
# 正态性检验的目的是为了检测一组数据是否服从正态分布，是否表现出正态分布的特性。正态性检验的方法有很多，包括QQ图、KS检验、SW检验、JB检验等等。

# %%
from IPython.display import Image
Image(filename = 'C:/Users/dash2/Pictures/Screenshots/屏幕截图 2024-08-10 200935.png')

# %%
from IPython.display import Image
Image(filename="C:/Users/dash2/Pictures/Screenshots/屏幕截图 2024-08-10 200941.png")

# %% [markdown]
# QQ图

# %%
import numpy as np  
import matplotlib.pyplot as plt  
# 生成标准正态分布的数据  
data = np.random.normal(0, 1, 1000)  
#Python绘制QQ图的方法集成在statsmodels当中，通过如下方式调用：
import statsmodels.api as sm
import matplotlib.pyplot as plt
# 创建 Q-Q 图，并增加 45度线
fig = sm.qqplot(data, line='45')
plt.show()

# %% [markdown]
# 从图中可以看到，蓝色散点表示样本取值与理论分布的关系，横坐标为理论分布的各个分位点，而纵坐标为样本分位点，它们近似分布在一条直线附近，因此可以初步判断它们服从正态分布。但这只是一种现象，是否真的服从正态分布还是要通过假设检验说明。

# %%
import scipy.stats as st
# 执行Shapiro-Wilk正态性检验
statistic , p_value =st.shapiro(data)
# 输出检验结果
print("Shapiro-Wilk统计量:", statistic)
print("p-value:", p_value)
# Out:
# Shapiro-Wilk统计量: 0.9981518438453021
# p-value: 0.3521570116962181

# %% [markdown]
# 得到Shapiro-Wilk统计量等于 0.9973，概率值0.098>0.05，无法拒绝原假设。因此，认为数据data具备正态性。

# %%
statistic_1 ,p_value_1 = st.kstest(data,'norm')
print('K-S统计量', statistic_1)
print('p-value', p_value_1)
# Out:
# K-S统计量 0.02290865209699433
# p-value 0.6615126165051044

# %%
statistic_2  ,p_value_2 = st.jarque_bera(data)
print('J-S统计量', statistic_2)
print('p-value', p_value_2)
# Out:
# J-S统计量 1.9900666214075942
# p-value 0.3697111290010318

# %% [markdown]
# 得到的结果概率也都超过0.05，认为数据是服从正态分布的。在kstest函数中，如果要使用它进行正态性检验，要在后面的参数里选择’norm’表明需要做的检验是正态性检验
